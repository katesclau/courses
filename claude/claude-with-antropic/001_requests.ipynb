# %% [markdown]
# ## Install Dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.72.0-py3-none-any.whl (357 kB)
#      |████████████████████████████████| 357 kB 3.2 MB/s eta 0:00:01
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.5.2-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 9.6 MB/s  eta 0:00:01
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#      |████████████████████████████████| 344 kB 12.3 MB/s eta 0:00:01
# Collecting docstring-parser<1,>=0.15
#   Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Collecting httpx<1,>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (4.13.2)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 13.2 MB/s eta 0:00:01
# Collecting exceptiongroup>=1.0.2; python_version < "3.11"
#   Using cached exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic) (2.8)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2019.11.28)
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 3.3 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: exceptiongroup, sniffio, anyio, jiter, docstring-parser, h11, httpcore, httpx, distro, pydantic-core, annotated-types, pydantic, anthropic, python-dotenv
# Successfully installed annotated-types-0.7.0 anthropic-0.72.0 anyio-4.5.2 distro-1.9.0 docstring-parser-0.18.0 exceptiongroup-1.3.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.9.1 pydantic-2.10.6 pydantic-core-2.27.2 python-dotenv-1.0.1 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load env variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %% [markdown]
# ## Define Helper functions

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages, model="claude-haiku-4-5"):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return response.content[0].text

def request_user_input(messages):
    user_input = input("You: ")
    add_user_message(messages, user_input)

# %% [markdown]
# ## Conversation

# %%
messages = []
user_input = ""
while user_input != "exit":
    request_user_input(messages)
    response = chat(messages)
    add_assistant_message(messages, response)
    print(response)
# Out:
# Hey! How's it going? What can I help you with today?
# Absolutely! I'd be happy to help you plan a voyage. I can assist with things like:
#
# - **Route planning** - helping you figure out where to go and how to get there
# - **Destination ideas** - suggesting places based on your interests and constraints
# - **Travel logistics** - accommodation, transportation, timing, budgeting
# - **Itinerary building** - structuring a day-by-day plan
# - **Practical tips** - what to pack, best times to visit, safety info, etc.
#
# To get started, it would help to know:
# - Where are you thinking of going (or what region/type of trip)?
# - How long do you have?
# - What's your approximate budget?
# - What kind of experiences are you looking for?
# - Any specific interests or constraints?
#
# Let me know and we can dive in! ⛵
