# %% [markdown]
# ## Install Dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /home/katesclau/.local/lib/python3.8/site-packages (0.72.0)
# Requirement already satisfied: python-dotenv in /home/katesclau/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: sniffio in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (2.10.6)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (4.13.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (4.5.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.9.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpcore==1.* in /home/katesclau/.local/lib/python3.8/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2.8)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2019.11.28)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/katesclau/.local/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/katesclau/.local/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.27.2)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in /home/katesclau/.local/lib/python3.8/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/katesclau/.local/lib/python3.8/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load env variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %% [markdown]
# ## Define Helper functions

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages, prompt=None, model="claude-haiku-4-5"):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return response.content[0].text

def request_user_input(messages):
    user_input = input("You: ")
    add_user_message(messages, user_input)
    return user_input

# %% [markdown]
# ## System Prompt

# %%
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

# %% [markdown]
# ## Conversation

# %%
messages = []
user_input = ""
while user_input != "exit":
    user_input = request_user_input(messages)
    response = chat(messages, prompt=system_prompt)
    add_assistant_message(messages, response)
    print(response)
# Out:
# # Absolutely! I'd be happy to help with math.
#
# Feel free to share whatever problems or concepts you're working on, and I'll do my best to:
# - Explain the steps clearly
# - Help you understand the underlying concepts
# - Work through examples with you
#
# What math topics do you need help with?
# # Great! The Frobenius equation is an interesting problem in number theory.
#
# Let me give you an overview, and then we can dive into specifics based on what you need.
#
# ## What is the Frobenius Equation?
#
# The **Frobenius coin problem** asks: Given two coprime positive integers *a* and *b* (where gcd(a,b) = 1), what is the **largest amount that cannot be represented** as a non-negative integer combination of *a* and *b*?
#
# In equation form:
# $$ax + by = n$$
#
# where we want to find which values of *n* cannot be solved with non-negative integers *x, y ≥ 0*.
#
# ## The Frobenius Number Formula
#
# For two coprime integers *a* and *b*, the **Frobenius number** (largest impossible value) is:
#
# $$g(a,b) = ab - a - b$$
#
# ### Example
# If *a* = 3 and *b* = 5:
# - g(3,5) = 3·5 - 3 - 5 = 15 - 8 = **7**
# - So 7 is the largest number that **cannot** be made with 3¢ and 5¢ coins
#
# ---
#
# **What specifically would you like help with?**
# - Do you have a particular Frobenius problem to solve?
# - Need help verifying the formula?
# - Want to understand why this formula works?
# # Goodbye!
#
# Feel free to come back anytime you need help with math or anything else. Good luck! 👋
# # Goodbye again! 👋
#
# I'm here whenever you need help. Take care!
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 5
#       3 while user_input != "exit":
#       4     request_user_input(messages)
# ----> 5     response = chat(messages, prompt=system_prompt)
#       6     add_assistant_message(messages, response)
#       7     print(response)
#
# Cell In[8], line 8, in chat(messages, prompt, model)
#       7 def chat(messages, prompt=None, model="claude-haiku-4-5"):
# ----> 8     response = client.messages.create(
#       9         model=model,
#      10         max_tokens=1000,
#      11         messages=messages,
#      12     )
#      13     return response.content[0].text
#
# File ~/.local/lib/python3.8/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/anthropic/resources/messages/messages.py:927, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     920 if model in DEPRECATED_MODELS:
#     921     warnings.warn(
#     922         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     923         DeprecationWarning,
#     924         stacklevel=3,
#     925     )
# --> 927 return self._post(
#     928     "/v1/messages",
#     929     body=maybe_transform(
#     930         {
#     931             "max_tokens": max_tokens,
#     932             "messages": messages,
#     933             "model": model,
#     934             "metadata": metadata,
#     935             "service_tier": service_tier,
#     936             "stop_sequences": stop_sequences,
#     937             "stream": stream,
#     938             "system": system,
#     939             "temperature": temperature,
#     940             "thinking": thinking,
#     941             "tool_choice": tool_choice,
#     942             "tools": tools,
#     943             "top_k": top_k,
#     944             "top_p": top_p,
#     945         },
#     946         message_create_params.MessageCreateParamsStreaming
#     947         if stream
#     948         else message_create_params.MessageCreateParamsNonStreaming,
#     949     ),
#     950     options=make_request_options(
#     951         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     952     ),
#     953     cast_to=Message,
#     954     stream=stream or False,
#     955     stream_cls=Stream[RawMessageStreamEvent],
#     956 )
#
# File ~/.local/lib/python3.8/site-packages/anthropic/_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1312 def post(
#    1313     self,
#    1314     path: str,
#    (...)
#    1321     stream_cls: type[_StreamT] | None = None,
#    1322 ) -> ResponseT | _StreamT:
#    1323     opts = FinalRequestOptions.construct(
#    1324         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325     )
# -> 1326     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.8/site-packages/anthropic/_base_client.py:1114, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1111             err.response.read()
#    1113         log.debug("Re-raising status error")
# -> 1114         raise self._make_status_error_from_response(err.response) from None
#    1116     break
#    1118 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.8: user messages must have non-empty content'}, 'request_id': 'req_011CaRATq95hV2iKxinnzgUW'}
