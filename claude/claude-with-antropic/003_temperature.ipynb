# %% [markdown]
# ## Install Dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /home/katesclau/.local/lib/python3.8/site-packages (0.72.0)
# Requirement already satisfied: python-dotenv in /home/katesclau/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (4.5.2)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (4.13.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (2.10.6)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.9.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: sniffio in /home/katesclau/.local/lib/python3.8/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic) (2.8)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in /home/katesclau/.local/lib/python3.8/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/katesclau/.local/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/katesclau/.local/lib/python3.8/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2019.11.28)
# Requirement already satisfied: httpcore==1.* in /home/katesclau/.local/lib/python3.8/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/katesclau/.local/lib/python3.8/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load env variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-4-6"

# %% [markdown]
# ## Define Helper functions

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages, prompt=None, model="claude-sonnet-4-5", temperature=0.5):
    params = {
        "max_tokens": 1000,
        "messages": messages,
    }
    if prompt:
        params["system"] = prompt
    if temperature:
        params["temperature"] = temperature
    if model:
        params["model"] = model
    response = client.messages.create(**params)
    return response.content[0].text

def request_user_input(messages):
    user_input = input("You: ")
    add_user_message(messages, user_input)
    return user_input

# %% [markdown]
# ## System Prompt

# %%
system_prompt = """
You are a System Architect, tasked with designing a system to solve a problem.
You will be given a problem statement and a list of requirements.
You will need to design a system to solve the problem.
You will need to provide a high-level overview of the system, including the main components and how they will work together.
You will need to provide a list of potential technologies to use.
"""

# %% [markdown]
# ## Brainstorming

# %%
messages = []
user_input = ""
while user_input != "exit":
    user_input = request_user_input(messages)
    response = chat(messages, prompt=system_prompt, temperature=0.6)
    add_assistant_message(messages, response)
    print(response)
# Out:
# # Aggregation System Design for Multi-Source Data Consolidation
#
# I'll design a comprehensive system for aggregating data from multiple sources with schema tracking and downstream distribution.
#
# ## High-Level System Overview
#
# ### Core Components
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │                    INGESTION LAYER                          │
# ├─────────────────────────────────────────────────────────────┤
# │  Source Connectors → Schema Detector → Data Validator       │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                 SCHEMA REGISTRY & VERSIONING                │
# ├─────────────────────────────────────────────────────────────┤
# │  Schema Store → Version Control → Schema Evolution Engine   │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │              DATA PROCESSING & NORMALIZATION                │
# ├─────────────────────────────────────────────────────────────┤
# │  ETL Pipeline → Data Mapper → Quality Checker               │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                   UNIFIED DATA STORE                        │
# ├─────────────────────────────────────────────────────────────┤
# │  Asset Catalog → Metadata Store → Time-Series/Object Store  │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                  DISTRIBUTION LAYER                         │
# ├─────────────────────────────────────────────────────────────┤
# │  API Gateway → Stream Publisher → Query Engine              │
# └─────────────────────────────────────────────────────────────┘
# ```
#
# ## Detailed Component Design
#
# ### 1. **Ingestion Layer**
#
# **Purpose:** Connect to multiple data sources and ingest data reliably
#
# **Sub-components:**
# - **Source Connectors**: Pluggable adapters for different data sources
#   - REST API connectors
#   - Database CDC (Change Data Capture) connectors
#   - File-based connectors (S3, SFTP, etc.)
#   - Streaming connectors (Kafka, Kinesis, etc.)
#
# - **Schema Detector**: Automatically infers schemas from incoming data
#   - Analyzes data structure
#   - Detects data types
#   - Identifies relationships
#
# - **Data Validator**: Ensures data quality at ingestion
#   - Schema compliance checking
#   - Data type validation
#   - Business rule validation
#
# ### 2. **Schema Registry & Versioning**
#
# **Purpose:** Central repository for all schemas with version control
#
# **Sub-components:**
# - **Schema Store**: Centralized schema repository
#   - Stores schemas in multiple formats (Avro, JSON Schema, Protobuf)
#   - Maintains schema lineage
#   - Tracks source-to-target mappings
#
# - **Version Control**: Manages schema evolution
#   - Semantic versioning (major.minor.patch)
#   - Backward/forward compatibility checking
#   - Schema diff capabilities
#
# - **Schema Evolution Engine**: Handles schema changes
#   - Auto-migration strategies
#   - Breaking change detection
#   - Schema merge/conflict resolution
#
# ### 3. **Data Processing & Normalization**
#
# **Purpose:** Transform and standardize data from various sources
#
# **Sub-components:**
# - **ETL Pipeline**: Orchestrates data transformation
#   - Parallel processing capabilities
#   - Error handling and retry logic
#   - Checkpointing for fault tolerance
#
# - **Data Mapper**: Transforms source schemas to target schemas
#   - Field mapping rules
#   - Data type conversions
#   - Aggregation logic
#
# - **Quality Checker**: Ensures data quality post-transformation
#   - Completeness checks
#   -
# # Enhanced Aggregation System Design with Caching & CDN
#
# I'll extend the design with caching layers, CDN, and flexible consumption patterns.
#
# ## Updated High-Level Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │                    INGESTION LAYER                          │
# ├─────────────────────────────────────────────────────────────┤
# │  Source Connectors → Schema Detector → Data Validator       │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                 SCHEMA REGISTRY & VERSIONING                │
# ├─────────────────────────────────────────────────────────────┤
# │  Schema Store → Version Control → Schema Evolution Engine   │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │              DATA PROCESSING & NORMALIZATION                │
# ├─────────────────────────────────────────────────────────────┤
# │  ETL Pipeline → Data Mapper → Quality Checker               │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                   UNIFIED DATA STORE                        │
# ├─────────────────────────────────────────────────────────────┤
# │  Asset Catalog → Metadata Store → Time-Series/Object Store  │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │              MULTI-TIER CACHE LAYER (NEW)                   │
# ├─────────────────────────────────────────────────────────────┤
# │  L1: Hot Cache → L2: Warm Cache → L3: Cold Cache           │
# │  Batch Assembler → Cache Invalidation → Prefetch Engine    │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │                    CDN LAYER (NEW)                          │
# ├─────────────────────────────────────────────────────────────┤
# │  Edge Locations → Static Asset Cache → Geo-Routing         │
# └──────────────────────┬──────────────────────────────────────┘
#                        ↓
# ┌─────────────────────────────────────────────────────────────┐
# │            DISTRIBUTION & CONSUMPTION LAYER                 │
# ├─────────────────────────────────────────────────────────────┤
# │  API Gateway → Stream Publisher → Query Engine              │
# │  Direct Fetch API → Batch API → Subscription Service       │
# └─────────────────────────────────────────────────────────────┘
# ```
#
# ## New/Enhanced Components
#
# ### 4. **Multi-Tier Cache Layer**
#
# **Purpose:** Optimize data access patterns with intelligent caching strategies
#
# #### **Sub-components:**
#
# **A. L1 Hot Cache (In-Memory)**
# - **Technology**: Redis Cluster or Hazelcast
# - **Characteristics**:
#   - Ultra-low latency (<1ms)
#   - Stores most frequently accessed assets
#   - Size: 10-20% of total dataset
#   - TTL: 5-15 minutes
# - **Data Stored**:
#   - Recently accessed individual assets
#   - Popular asset metadata
#   - Active schema versions
#   - Real-time aggregated metrics
#
# **B. L2 Warm Cache (Distributed Cache)**
# - **Technology**: Redis with persistence or Apache Ignite
# - **Characteristics**:
#   - Low latency (1-10ms)
#   - Larger capacity than L1
#   - Size: 40-60% of total dataset
#   - TT
# Understood! Feel free to come back anytime if you need help with system design or any other topics. Good luck with your aggregation system!
