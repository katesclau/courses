# %% [markdown]
# ## Install Dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load env variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-4-6"

# %% [markdown]
# ## Define Helper functions

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages, prompt=None, model="claude-sonnet-4-5", temperature=0.5):
    params = {
        "max_tokens": 1000,
        "messages": messages,
    }
    if prompt:
        params["system"] = prompt
    if temperature:
        params["temperature"] = temperature
    if model:
        params["model"] = model
    response = client.messages.create(**params)
    return response.content[0].text

def request_user_input(messages):
    user_input = input("You: ")
    add_user_message(messages, user_input)
    return user_input

def chat_stream(messages, prompt=None, model="claude-sonnet-4-5", temperature=0.5): 
    params = {
        "max_tokens": 1000,
        "messages": messages,
    }
    if prompt:
        params["system"] = prompt
    if temperature:
        params["temperature"] = temperature
    if model:
        params["model"] = model
    return client.messages.stream(**params)

# %% [markdown]
# ## System Prompt

# %%
system_prompt = """
You are a System Architect, tasked with designing a system to solve a problem.
You will be given a problem statement and a list of requirements.
You will need to design a system to solve the problem.
You will need to provide a high-level overview of the system, including the main components and how they will work together.
You will need to provide a list of potential technologies to use.
"""

# %% [markdown]
# ## Brainstorming

# %%
messages = []
user_input = ""
while user_input != "exit":
    user_input = request_user_input(messages)
    with chat_stream(messages, prompt=system_prompt, temperature=0.6) as stream:
        for text in stream.text_stream:
            print(text, end="", flush=True)
        response = stream.get_final_message()
    print()
    add_assistant_message(messages, response.content[0].text)
# Out:
# # Hello! I'm ready to help you design a system.
#
# Please provide me with:
#
# 1. **Problem Statement** - What problem are we trying to solve?
# 2. **Requirements** - What are the functional and non-functional requirements?
# 3. **Any constraints** - Budget, timeline, existing systems to integrate with, etc.
#
# Once you share these details, I'll provide:
# - A high-level system architecture
# - Main components and their interactions
# - Data flow diagrams (if needed)
# - Recommended technology stack
# - Scalability and security considerations
#
# What system would you like me to help you architect?
# # Mobile App for Template-Based Document Creation - System Architecture
#
# ## Problem Statement
# Design a mobile application that allows users to create professional documents using pre-built templates, with customization capabilities and document management features.
#
# ## High-Level System Overview
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# ...
