# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete. Include criteria for the solution,
providing a description of the requirements for a proper solution output.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Criteria for the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution Criteria:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 3.8333333333333335

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_arns_from_cloudtrail_logs(logs):\n    \"\"\"\n    Extract AWS resource ARNs from CloudTrail logs.\n    \"\"\"\n    arn_pattern = r'arn:aws:[a-z0-9\\-]*:[a-z0-9\\-]*:[0-9]*:[a-z0-9\\-\\/*]*'\n    \n    arns = set()\n    \n    if isinstance(logs, str):\n        try:\n            logs = json.loads(logs)\n        except json.JSONDecodeError:\n            matches = re.findall(arn_pattern, logs, re.IGNORECASE)\n            return list(set(matches))\n    \n    def extract_from_object(obj):\n        if isinstance(obj, dict):\n            for key, value in obj.items():\n                if isinstance(value, str):\n                    matches = re.findall(arn_pattern, value, re.IGNORECASE)\n                    arns.update(matches)\n                elif isinstance(value, (dict, list)):\n                    extract_from_object(value)\n        elif isinstance(obj, list):\n            for item in obj:\n                extract_from_object(item)\n        elif isinstance(obj, str):\n            matches = re.findall(arn_pattern, obj, re.IGNORECASE)\n            arns.update(matches)\n    \n    extract_from_object(logs)\n    return list(arns)\n\nif __name__ == \"__main__\":\n    if len(sys.argv) > 1:\n        input_data = sys.argv[1]\n    else:\n        input_data = sys.stdin.read()\n    \n    result = extract_arns_from_cloudtrail_logs(input_data)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Extract AWS resource ARNs from CloudTrail logs",
#       "format": "regex",
#       "solution_criteria": "The regex should match valid AWS ARNs in the format 'arn:aws:service:region:account-id:resource' and capture all occurrences in a log file. It should handle various AWS services (EC2, S3, RDS, etc.) and optional resource types."
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates good architectural decisions for handling variable input formats and nested JSON structures typical of CloudTrail logs. However, the ARN regex pattern is significantly underspecified for production use. The pattern `[a-z0-9\\-]*` for service and region fields permits empty matches, and the pattern lacks support for AWS partitions and complex resource identifiers that appear in real CloudTrail data (e.g., IAM roles with paths, S3 objects with colons). A more rigorous pattern based on AWS ARN specification (RFC 3986) would be required for reliable extraction across diverse AWS services."
#   },
#   {
#     "output": "\nimport re\nimport json\nimport boto3\nfrom typing import Dict, List, Tuple\n\ndef parse_s3_bucket_configuration(bucket_name: str) -> Dict:\n    \"\"\"Parse AWS S3 bucket configuration\"\"\"\n    s3_client = boto3.client('s3')\n    \n    try:\n        # Get bucket tagging\n        tags_response = s3_client.get_bucket_tagging(Bucket=bucket_name)\n        tags = {tag['Key']: tag['Value'] for tag in tags_response.get('TagSet', [])}\n        \n        # Get bucket versioning\n        versioning = s3_client.get_bucket_versioning(Bucket=bucket_name)\n        \n        # Get bucket encryption\n        try:\n            encryption = s3_client.get_bucket_encryption(Bucket=bucket_name)\n        except s3_client.exceptions.ServerSideEncryptionConfigurationNotFoundError:\n            encryption = {}\n        \n        # Get bucket lifecycle\n        try:\n            lifecycle = s3_client.get_bucket_lifecycle_configuration(Bucket=bucket_name)\n        except s3_client.exceptions.NoSuchLifecycleConfiguration:\n            lifecycle = {}\n        \n        # Get bucket ACL\n        acl = s3_client.get_bucket_acl(Bucket=bucket_name)\n        \n        return {\n            'bucket_name': bucket_name,\n            'tags': tags,\n            'versioning': versioning.get('Status', 'Not Set'),\n            'encryption': encryption,\n            'lifecycle': lifecycle,\n            'acl': acl,\n            'success': True\n        }\n    except Exception as e:\n        return {\n            'bucket_name': bucket_name,\n            'success': False,\n            'error': str(e)\n        }\n\ndef validate_required_tags(bucket_config: Dict, required_tags: List[str]) -> Tuple[bool, Dict]:\n    \"\"\"Validate that bucket has all required tags\"\"\"\n    bucket_tags = bucket_config.get('tags', {})\n    \n    validation_result = {\n        'bucket_name': bucket_config.get('bucket_name'),\n        'required_tags': required_tags,\n        'missing_tags': [],\n        'present_tags': [],\n        'all_present': True\n    }\n    \n    for tag in required_tags:\n        if tag in bucket_tags:\n            validation_result['present_tags'].append(tag)\n        else:\n            validation_result['missing_tags'].append(tag)\n            validation_result['all_present'] = False\n    \n    return validation_result['all_present'], validation_result\n\ndef validate_s3_bucket_complete(bucket_name: str, required_tags: List[str]) -> Dict:\n    \"\"\"Complete validation of S3 bucket configuration and tags\"\"\"\n    config = parse_s3_bucket_configuration(bucket_name)\n    \n    if not config.get('success'):\n        return {\n            'bucket_name': bucket_name,\n            'validation_success': False,\n            'error': config.get('error'),\n            'configuration': None,\n            'tag_validation': None\n        }\n    \n    is_valid, tag_validation = validate_required_tags(config, required_tags)\n    \n    return {\n        'bucket_name': bucket_name,\n        'validation_success': is_valid,\n        'configuration': config,\n        'tag_validation': tag_validation\n    }\n\nif __name__ == \"__main__\":\n    required_tags = ['Environment', 'Owner', 'Application']\n    result = validate_s3_bucket_complete('my-bucket', required_tags)\n    print(json.dumps(result, indent=2, default=str))\n",
#     "test_case": {
#       "task": "Parse AWS S3 bucket configuration and validate required tags",
#       "format": "json",
#       "solution_criteria": "A JSON object representing an S3 bucket configuration that includes properties for bucket name, region, versioning status, encryption settings, and a tags object. Must include at least 5 standard AWS tags such as Environment, Owner, CostCenter, and Project."
#     },
#     "score": 2.5,
#     "reasoning": "The solution provides functional AWS S3 configuration parsing and tag validation, but falls short of meeting the stated criteria. The output is missing the bucket region, doesn't ensure at least 5 standard AWS tags are present (Environment, Owner, CostCenter, Project, and one more), and returns non-serializable boto3 response objects that would fail JSON serialization without the `default=str` workaround. The code structure is sound but needs refinement to match specification requirements."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Union, List, Dict, Any\n\ndef validate_iam_policy_statement(statement: Union[Dict[str, Any], str]) -> Dict[str, bool]:\n    \"\"\"\n    Validate AWS IAM policy statements.\n    \n    Returns a dict with validation results for each check.\n    \"\"\"\n    if isinstance(statement, str):\n        try:\n            statement = json.loads(statement)\n        except json.JSONDecodeError:\n            return {\"valid\": False, \"error\": \"Invalid JSON\"}\n    \n    if not isinstance(statement, dict):\n        return {\"valid\": False, \"error\": \"Statement must be a dictionary\"}\n    \n    results = {\n        \"valid\": True,\n        \"has_effect\": False,\n        \"has_action\": False,\n        \"has_resource\": False,\n        \"valid_effect\": False,\n        \"valid_action_format\": False,\n        \"valid_resource_format\": False,\n        \"valid_principal_format\": False,\n    }\n    \n    # Check Effect\n    if \"Effect\" in statement:\n        results[\"has_effect\"] = True\n        if statement[\"Effect\"] in [\"Allow\", \"Deny\"]:\n            results[\"valid_effect\"] = True\n        else:\n            results[\"valid\"] = False\n    else:\n        results[\"valid\"] = False\n    \n    # Check Action\n    if \"Action\" in statement:\n        results[\"has_action\"] = True\n        action = statement[\"Action\"]\n        if isinstance(action, str):\n            if re.match(r'^[a-z]+:[a-zA-Z0-9\\-\\*]+$', action) or action == \"*\":\n                results[\"valid_action_format\"] = True\n            else:\n                results[\"valid\"] = False\n        elif isinstance(action, list) and len(action) > 0:\n            valid_actions = all(\n                isinstance(a, str) and (re.match(r'^[a-z]+:[a-zA-Z0-9\\-\\*]+$', a) or a == \"*\")\n                for a in action\n            )\n            if valid_actions:\n                results[\"valid_action_format\"] = True\n            else:\n                results[\"valid\"] = False\n        else:\n            results[\"valid\"] = False\n    else:\n        results[\"valid\"] = False\n    \n    # Check Resource (optional for some statement types)\n    if \"Resource\" in statement:\n        results[\"has_resource\"] = True\n        resource = statement[\"Resource\"]\n        if isinstance(resource, str):\n            if re.match(r'^arn:[a-z0-9\\-]+:[a-z0-9\\-]+:[a-z0-9\\-]*:[0-9]*:[a-zA-Z0-9\\-\\*/:]+$', resource) or resource == \"*\":\n                results[\"valid_resource_format\"] = True\n            else:\n                results[\"valid\"] = False\n        elif isinstance(resource, list) and len(resource) > 0:\n            valid_resources = all(\n                isinstance(r, str) and (re.match(r'^arn:[a-z0-9\\-]+:[a-z0-9\\-]+:[a-z0-9\\-]*:[0-9]*:[a-zA-Z0-9\\-\\*/:]+$', r) or r == \"*\")\n                for r in resource\n            )\n            if valid_resources:\n                results[\"valid_resource_format\"] = True\n            else:\n                results[\"valid\"] = False\n        else:\n            results[\"valid\"] = False\n    \n    # Check Principal (for trust policies)\n    if \"Principal\" in statement:\n        principal = statement[\"Principal\"]\n        if isinstance(principal, str):\n            if principal == \"*\":\n                results[\"valid_principal_format\"] = True\n            else:\n                results[\"valid\"] = False\n        elif isinstance(principal, dict):\n            valid_principal = True\n            for key, value in principal.items():\n                if key not in [\"AWS\", \"Service\", \"Federated\", \"CanonicalUser\"]:\n                    valid_principal = False\n                if isinstance(value, str):\n                    if not (re.",
#     "test_case": {
#       "task": "Create a Python function to validate AWS IAM policy statements",
#       "format": "python",
#       "solution_criteria": "A single Python function that accepts a dictionary representing an IAM policy statement and validates that it contains required fields (Effect, Action, Resource), has valid Effect values (Allow/Deny), and returns a boolean indicating validity along with error messages for any violations."
#     },
#     "score": 1.5,
#     "reasoning": "While the solution demonstrates good intent with multi-faceted validation and flexible input handling, it falls short on several critical fronts. The truncated code makes it immediately non-functional. More fundamentally, it misaligns with the stated criteria by providing a complex dictionary response instead of a boolean with error messages. The logic also incorrectly enforces Resource as mandatory, which contradicts AWS IAM policy statement specifications. The regex patterns, while reasonable, have accuracy issues for edge cases. The incomplete state of the code and deviation from specified return format are the primary disqualifying factors."
#   }
# ]
